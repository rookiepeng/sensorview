# %%
import os
import pandas as pd
import numpy as np

# %%
det_list = pd.read_pickle('./data/20190410_Overpass/20190427_0012_Overpass1.pkl')

# %%
from viz import get_figure_data

# %%
# %timeit get_figure_data(det_list[det_list['Frame'] == 1])
# Out:
# 8.01 ms ± 254 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.io import loadmat

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.set_style('darkgrid')

# %%
data_set = 'ARDP003R1_Overpass_20190410'
path = './data/'+data_set+'/'

files = []
for r, d, f in os.walk(path):
    for file in f:
        if '.pkl' in file:
            files.append(file)
    break

# %%
det_list = pd.DataFrame()

# for f in files:
#     det_list = det_list.append(pd.read_pickle(path+f), ignore_index=True)

det_list = pd.read_pickle(path+files[0])
len(det_list)
# Out:
# 53781

# %%
ax = sns.barplot(x="AFType",
                 y="Frame",
                 #                  hue="LookName",
                 data=det_list,
                 estimator=lambda x: len(x) / len(det_list)*100)
ax.set(ylabel="Percentage")
plt.title(data_set)
plt.savefig(data_set+'_aftype.svg')

# %%
ax = sns.barplot(x="AzConf",
                 y="Frame",
#                  hue="LookName",
                 data=det_list,
                 estimator=lambda x: len(x) / len(det_list)*100)
ax.set(ylabel="Percentage")
plt.title(data_set)
plt.savefig(data_set+'_azconf.svg')

# %%
ax = sns.barplot(x="ElConf",
                 y="Frame",
#                  hue="LookName",
                 data=det_list,
                 estimator=lambda x: len(x) / len(det_list)*100)
ax.set(ylabel="Percentage")
plt.title(data_set)
plt.savefig(data_set+'_elconf.svg')

# %%
ax = sns.kdeplot(det_list['Elevation'], shade=True, shade_lowest=False)
ax = sns.kdeplot(det_list['Azimuth'], shade=True, shade_lowest=False)
ax.set(ylabel="Density")
ax.set(xlabel="Angle")
plt.title(data_set)
plt.savefig(data_set+'_az_el_dist.svg')

# %%
ax = sns.kdeplot(det_list['Elevation'], shade=True, shade_lowest=False)
ax = sns.kdeplot(det_list['Azimuth'], shade=True, shade_lowest=False)
ax.set(ylabel="Density")
ax.set(xlabel="Angle")
plt.title(data_set)
plt.savefig(data_set+'_az_el_dist.svg')

# %%
plt.plot(det_list['AzConf'])

# %%
ax = sns.kdeplot(det_list['Elevation'], det_list['Azimuth'],
                 cmap="Reds", shade=True, shade_lowest=False)
plt.title(data_set)
plt.savefig(data_set+'_el_az.svg')

# %%
ax = sns.kdeplot(det_list['Elevation'], det_list['SNR'],
                 cmap="Reds", shade=True, shade_lowest=False)
plt.title(data_set)
plt.savefig(data_set+'_el_snr.svg')

# %%
ax = sns.kdeplot(det_list['Elevation'], det_list['Range'],
                 cmap="Reds", shade=True, shade_lowest=False)
plt.title(data_set)
plt.savefig(data_set+'_el_range.svg')

# %%
ax = sns.kdeplot(det_list['Elevation'], det_list['Speed'],
                 cmap="Reds", shade=True, shade_lowest=False)
plt.title(data_set)
plt.savefig(data_set+'_el_speed.svg')

# %%
ax = sns.kdeplot(det_list['AzConf'], det_list['SNR'],
                 cmap="Reds", shade=True, shade_lowest=False)
plt.title(data_set)
plt.savefig(data_set+'_azconf_snr.svg')

# %%
ax = sns.kdeplot(det_list['AzConf'], det_list['ElConf'],
                 cmap="Reds", shade=True, shade_lowest=False)
plt.title(data_set)
plt.savefig(data_set+'_azconf_elconf.svg')

# %%
det_list
# Out:
#          Frame  SubFrame  LookType LookName      Range     Speed  \
# 0       1682.0       0.0       1.0     MRLL  59.909472 -2.357191
# 1       1682.0       0.0       1.0     MRLL  59.909472 -2.357191
# 2       1682.0       0.0       1.0     MRLL  59.909472 -2.357191
# 3       1682.0       0.0       1.0     MRLL  76.070900 -3.070248
# 4       1682.0       0.0       1.0     MRLL  76.070900 -3.070248
# ...        ...       ...       ...      ...        ...       ...
# 302824  3971.0       3.0       4.0     LRML  94.696279  1.167591
# 302825  3971.0       3.0       4.0     LRML  94.696279  1.167591
# 302826  3971.0       3.0       4.0     LRML  94.696279  1.167591
# 302827  3971.0       3.0       4.0     LRML  56.918052  0.735067
# 302828  3971.0       3.0       4.0     LRML  86.537328  0.262547
#
#         UnfoldedSpeed  DoppShift  DoppUnfoldFlag    Azimuth  ...        SNR  \
# 0           29.589599   3.141593             0.0 -14.201999  ...  20.990179
# 1           29.589599   3.141593             0.0 -14.315847  ...  20.990179
# 2           29.589599   3.141593             0.0 -14.274629  ...  20.990179
# 3           -3.070248   0.000000             0.0  -5.252477  ...  14.183854
# 4           -3.070248   0.000000             0.0  -5.446619  ...  14.183854
# ...               ...        ...             ...        ...  ...        ...
# 302824     -25.771359   3.141593             0.0   6.599026  ...  11.905707
# 302825     -25.771359   3.141593             0.0   6.676843  ...  11.905707
# 302826     -25.771359   3.141593             0.0  -0.429308  ...  11.905707
# 302827       0.735067   0.000000             0.0   0.170997  ...  22.475550
# 302828       0.262547   0.000000             0.0  -0.021497  ...   8.763796
#
#               RCS  VehYawRate   VehSpeed    Latitude    Longitude    Height  \
# 0        3.880190    -0.01839  28.013911   14.694896    58.065145 -1.282124
# 1        3.880190    -0.01839  28.013911   14.755046    57.819531 -5.323094
# 2        3.880190    -0.01839  28.013911   14.765791    58.035863  1.718973
# 3       -4.516952    -0.01839  28.013911    6.963870    75.751306  0.161138
# 4       -4.516952    -0.01839  28.013911    7.170849    75.206485  8.907600
# ...           ...         ...        ...         ...          ...       ...
# 302824  -1.370832    -0.12828  24.622242   91.272820  1128.796239  8.964904
# 302825  -1.370832    -0.12828  24.622242   91.166278  1129.202944  2.173099
# 302826  -1.370832    -0.12828  24.622242  102.824924  1127.866565 -1.486697
# 302827  22.919861    -0.12828  24.622242   95.577562  1090.793928  0.021184
# 302828  -7.908409    -0.12828  24.622242  100.781035  1119.950428 -0.724613
#
#           VehYaw    VehLat      VehLong
# 0      -0.000000   0.00000     0.000000
# 1      -0.000000   0.00000     0.000000
# 2      -0.000000   0.00000     0.000000
# 3      -0.000000   0.00000     0.000000
# 4      -0.000000   0.00000     0.000000
# ...          ...       ...          ...
# 302824 -9.727438  86.12808  1034.665758
# 302825 -9.727438  86.12808  1034.665758
# 302826 -9.727438  86.12808  1034.665758
# 302827 -9.727438  86.12808  1034.665758
# 302828 -9.727438  86.12808  1034.665758
#
# [302829 rows x 25 columns]

# %%
filtered_list = det_list

# filtered_list = filtered_list[filtered_list['Target_loc_y'] > 90]
# filtered_list = filtered_list[filtered_list['Target_loc_y'] < 115]
# filtered_list = filtered_list[filtered_list['LookType'] == 3]
# filtered_list = filtered_list[filtered_list['Speed'] > -20]
# filtered_list = filtered_list[filtered_list['Speed'] < -15]
filtered_list = filtered_list[filtered_list['AzConf'] == 0]
filtered_list = filtered_list[filtered_list['ElConf'] == 0]


filtered_list = filtered_list.reset_index()
det_list = filtered_list
